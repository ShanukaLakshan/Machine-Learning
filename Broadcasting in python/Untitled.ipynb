# %% [markdown]
# # Broadcastiong in Python
#
# ** **
# **Test**

# %%
import numpy as np

# %%
A = np.array([[56.0,0.0,4.4,68.0],[1.2,104.0,52.0,8.0],[1.8,135.0,99.0,0.9]])

# %%
print(A)
# Out:
# [[ 56.    0.    4.4  68. ]
#  [  1.2 104.   52.    8. ]
#  [  1.8 135.   99.    0.9]]

# %%
cal_sum = A.sum(axis=0)
cal_sum
# Out:
# array([ 59. , 239. , 155.4,  76.9])

# %%
percentage = 100 * A / cal_sum.reshape(1,4)
print(percentage)
# Out:
# [[94.91525424  0.          2.83140283 88.42652796]
#  [ 2.03389831 43.51464435 33.46203346 10.40312094]
#  [ 3.05084746 56.48535565 63.70656371  1.17035111]]

# %%
# 2nd

# %%
a = np.random.rand(5)
print(a.shape)
print(a)
# Out:
# (5,)
# [0.48388552 0.8600633  0.18698223 0.02270617 0.15819561]

# %%
print((a.T).shape)
print(a.T)
# Out:
# (5,)
# [0.48388552 0.8600633  0.18698223 0.02270617 0.15819561]

# %%
print(np.dot(a,a.T))
# Out:
# 1.0343578437746686

# %%
# test
b = np.random.rand(5,1)
print(b.shape)
print(b)
# Out:
# (5, 1)
# [[0.73771155]
#  [0.425542  ]
#  [0.57123239]
#  [0.99029175]
#  [0.23869963]]

# %%
print(b.T)
print((b.T).shape)
# Out:
# [[0.73771155 0.425542   0.57123239 0.99029175 0.23869963]]
# (1, 5)

# %%
print(np.dot(b.T,b))
print(np.dot(b,b.T))
# Out:
# [[2.08926604]]
# [[0.54421833 0.31392725 0.42140473 0.73054967 0.17609148]
#  [0.31392725 0.18108599 0.24308337 0.42141073 0.10157672]
#  [0.42140473 0.24308337 0.32630645 0.56568673 0.13635296]
#  [0.73054967 0.42141073 0.56568673 0.98067776 0.23638228]
#  [0.17609148 0.10157672 0.13635296 0.23638228 0.05697751]]

# %% [markdown]
# # Logistic Regression cost function
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
