# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# data = pd.read_csv('vgsales.csv')
data = pd.read_csv('book.csv')

# %%
# plt.scatter(data.Year,data.Global_Sales,color='blue')
# plt.xlabel('Year')
# plt.ylabel('Global_Sales')

plt.scatter(data.videos,data.views,color='blue')
plt.xlabel('Videos')
plt.ylabel('Views')
# Out:
# Text(0, 0.5, 'Views')

# %%
data.videos
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
data.views
# Out:
# 0    34000
# 1    41000
# 2    42500
# 3    54300
# 4    56000
# Name: views, dtype: int64

# %%
x = np.array(data.videos.values)
x
# Out:
# array([30, 40, 50, 60, 70], dtype=int64)

# %%
y = np.array(data.views.values)
y
# Out:
# array([34000, 41000, 42500, 54300, 56000], dtype=int64)

# %%
model = LinearRegression()
# need to give two dimentional array
model.fit(x.reshape((-1,1)),y)
# Out:
# LinearRegression()

# %%
new_x = np.array([45]).reshape((-1,1))

# %%
predict = model.predict(new_x)
predict
# Out:
# array([42695.])

# %%
plt.scatter(data.videos,data.views,color='blue')
m,c = np.polyfit(x,y,1)
plt.plot(x,m*x+c)

# %%
new_y = m*45+c

# %%
new_y
# Out:
# 42695.0
